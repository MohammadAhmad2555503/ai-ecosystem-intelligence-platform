# %% [markdown]
# # A/B Test Analysis Notebook
#
# This notebook documents how Step 6 analyses router logs and decides whether to ship, hold, or iterate.

# %%
from pathlib import Path
import json

result_path = Path('../data/evaluation/ab_test_results.json')
if result_path.exists():
    result = json.loads(result_path.read_text())
    result
